# %%
import requests
import os
import pandas as pd
from dotenv import load_dotenv
import duckdb

import API_functions as api

load_dotenv()

# %% [markdown]
# ### API Data

# %%
# Project ID
projectID = os.getenv("PROJECT_ID")

# Initialize project metadata
project_json = api.getProjectInfo(projectID)

# Get current album information
current_album_df = api.getCurrentAlbum(project_json)

# Generate listening history
history_df = api.getListeningHistory(project_json)

# %% [markdown]
# ### Database Handling

# %%
df = history_df.copy()

# %%
# Connect to duckDB
database_name = 'database'
con = duckdb.connect(f'data/{database_name}.duckdb')

# %%
# Create a table
table_name = 'project_data'
con.execute(f'CREATE TABLE {table_name} AS SELECT * FROM df')

# %%
# Verify the metadata from the DataFrame loading
schema_df = con.execute(f"DESCRIBE {table_name}").fetchdf()

schema_df

# %%
# Query the database
sql_statement = f"""
    SELECT
        *
    FROM
        {table_name}
"""

query_df = con.execute(sql_statement).fetchdf()

# %%
# Search the genres
sql_statement = f"""
SELECT
    uuid,
    artist,
    name,
    UNNEST(genres) AS genre
FROM {table_name}
"""

query_df = con.execute(sql_statement).fetchdf()
query_df

# %%
# Search the genres
sql_statement = f"""
SELECT
    uuid,
    artist,
    name,
    UNNEST(subGenres) AS subgenre
FROM {table_name}
"""

query_df = con.execute(sql_statement).fetchdf()
query_df

# %%
# Get both genre and subGenre
sql_statement = f"""
SELECT
    uuid,
    artist,
    name,
    g.genre,
    s.subgenre
FROM {table_name},
     UNNEST(genres) AS g(genre),
     UNNEST(subGenres) AS s(subgenre)
"""

query_df = con.execute(sql_statement).fetchdf()
query_df

# %% [markdown]
# ### Research
#
# - https://musicbrainz.org/doc/MusicBrainz_API
# - https://www.discogs.com/developers/#
